# %%
import pandas as pd

# %%
resorts = pd.read_csv('data/pistas.csv')
resorts
# Out:
#                                       Nombre del Resort  Rate  Estrellas  \
# 0                         KitzSki – Kitzbühel/Kirchberg   4.9        5.0
# 1                      Ischgl/Samnaun – Silvretta Arena   4.8        5.0
# 2                       SkiWelt Wilder Kaiser-Brixental   4.8        5.0
# 3     St. Anton/St. Christoph/Stuben/Lech/Zürs/Warth...   4.8        5.0
# 4                                    Serfaus-Fiss-Ladis   4.8        5.0
# ...                                                 ...   ...        ...
# 3112                                          ski-egypt   1.2        NaN
# 3113                        ski-mountain-park-sao-roque   1.1        NaN
# 3114                                   snowland-gramado   1.0        NaN
# 3115                             sky-resort-ulaanbaatar   2.0        NaN
# 3116                              troodos-mount-olympos   1.5        NaN
#
#       Km de Freeride     Continente      Pais             Estado  Altitud  \
# 0               45.0         Europe   Austria      Tyrol (Tirol)   2000.0
# 1               15.0         Europe   Austria      Tyrol (Tirol)   2872.0
# 2               26.0         Europe   Austria      Tyrol (Tirol)   1957.0
# 3              200.0         Europe   Austria      Tyrol (Tirol)   2811.0
# 4               28.0         Europe   Austria      Tyrol (Tirol)   2820.0
# ...              ...            ...       ...                ...      ...
# 3112             NaN         Africa     Egypt              Egypt    180.0
# 3113             NaN  South America    Brazil          Sao Paulo   1230.0
# 3114             NaN  South America    Brazil  Rio Grande do Sul    780.0
# 3115             2.0           Asia  Mongolia        Ulaanbaatar   1596.0
# 3116             NaN           Asia    Cyprus             Cyprus   1951.0
#
#       Facil  Intermedio  ...  Fiabilidad de la nieve  Orientacion de mapas  \
# 0     101.0        61.0  ...                     5.0                   5.0
# 1      47.0       142.0  ...                     5.0                   5.0
# 2     122.0       129.0  ...                     4.0                   4.0
# 3     132.0       123.0  ...                     5.0                   4.0
# 4      47.0       123.0  ...                     5.0                   5.0
# ...     ...         ...  ...                     ...                   ...
# 3112    0.5         0.0  ...                     NaN                   NaN
# 3113    0.3         0.0  ...                     NaN                   NaN
# 3114    0.1         0.0  ...                     NaN                   NaN
# 3115    3.0         2.0  ...                     4.0                   4.0
# 3116    1.0         2.0  ...                     NaN                   NaN
#
#       Limpieza e higiene Apres-ski  Snow parks  Esqui de fondo y senderos  \
# 0                    5.0       4.0         5.0                        5.0
# 1                    5.0       5.0         5.0                        4.0
# 2                    5.0       4.0         5.0                        5.0
# 3                    4.0       5.0         4.0                        4.0
# 4                    4.0       4.0         5.0                        4.0
# ...                  ...       ...         ...                        ...
# 3112                 NaN       NaN         NaN                        NaN
# 3113                 NaN       NaN         NaN                        NaN
# 3114                 NaN       NaN         NaN                        NaN
# 3115                 5.0       1.0         1.0                        2.0
# 3116                 NaN       NaN         NaN                        NaN
#
#       pais   latitude   longitude  ISO Code
# 0       AT  47.516231   14.550072       AUT
# 1       AT  47.516231   14.550072       AUT
# 2       AT  47.516231   14.550072       AUT
# 3       AT  47.516231   14.550072       AUT
# 4       AT  47.516231   14.550072       AUT
# ...    ...        ...         ...       ...
# 3112    EG  26.820553   30.802498       EGY
# 3113    BR -14.235004  -51.925280       BRA
# 3114    BR -14.235004  -51.925280       BRA
# 3115    MN  46.862496  103.846656       MNG
# 3116    CY  35.126413   33.429859       CYP
#
# [3117 rows x 26 columns]

# %%
resorts.columns
# Out:
# Index(['Nombre del Resort', 'Rate', 'Estrellas', 'Km de Freeride',
#        'Continente', 'Pais', 'Estado', 'Altitud', 'Facil', 'Intermedio',
#        'Dificil', 'Total de kilometros', 'Precio', 'Moneda',
#        'Tamaño del resort de esqui', 'Variedad de pistas',
#        'Fiabilidad de la nieve', 'Orientacion de mapas', 'Limpieza e higiene',
#        'Apres-ski', 'Snow parks', 'Esqui de fondo y senderos', 'pais',
#        'latitude', 'longitude', 'ISO Code'],
#       dtype='object')

# %%
pistas = resorts[['Nombre del Resort', 'Rate', 'Estrellas', 'Km de Freeride',
       'Continente', 'Pais', 'Estado', 'Altitud', 'Facil', 'Intermedio',
       'Dificil', 'Total de kilometros', 'Precio','latitude', 'longitude', 'ISO Code']]

# %%
# !pip install powerbiclient
# Out:
# Requirement already satisfied: powerbiclient in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from powerbiclient) (0.2.2)
# Requirement already satisfied: msal>=1.8.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from powerbiclient) (1.22.0)
# Requirement already satisfied: requests>=2.25.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from powerbiclient) (2.28.2)
# Requirement already satisfied: pandas in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from powerbiclient) (1.5.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from powerbiclient) (8.0.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient) (5.9.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient) (3.0.5)
# Requirement already satisfied: ipython>=6.1.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient) (8.10.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient) (6.21.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient) (4.0.5)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient) (2.6.0)
# Requirement already satisfied: cryptography<43,>=0.6 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient) (39.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from pandas->powerbiclient) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from pandas->powerbiclient) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from pandas->powerbiclient) (1.24.2)
# Requirement already satisfied: cffi>=1.12 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from cryptography<43,>=0.6->msal>=1.8.0->powerbiclient) (1.15.1)
# Requirement already satisfied: packaging in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (23.0)
# Requirement already satisfied: tornado>=6.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (6.2)
# Requirement already satisfied: pyzmq>=20 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (25.0.0)
# Requirement already satisfied: appnope in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (0.1.3)
# Requirement already satisfied: psutil in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (5.9.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (5.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (8.0.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (1.6.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (1.5.6)
# Requirement already satisfied: stack-data in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.6.2)
# Requirement already satisfied: pickleshare in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (3.0.36)
# Requirement already satisfied: backcall in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.2.0)
# Requirement already satisfied: decorator in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (2.14.0)
# Requirement already satisfied: six>=1.5 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->powerbiclient) (1.16.0)
# Requirement already satisfied: pycparser in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from cffi>=1.12->cryptography<43,>=0.6->msal>=1.8.0->powerbiclient) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient) (3.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/migueldefrutos/miniconda3/envs/toolkit/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient) (2.2.1)

# %%
from powerbiclient import QuickVisualize, get_dataset_config, Report
from powerbiclient.authentication import DeviceCodeLoginAuthentication

device_auth = DeviceCodeLoginAuthentication()

import pandas as pd
# Out:
# Performing device flow authentication. Please follow the instructions below.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CWV5D4CDT to authenticate.
#
# Device flow authentication successfully completed.
# You are now logged in .
#
# The result should be passed only to trusted code in your notebook.

# %%
# Create a Power BI report from your data
PBI_visualize = QuickVisualize(get_dataset_config(pistas), auth=device_auth)

# Render the new report
PBI_visualize
# Out:
# QuickVisualize()
